# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('classic')
import seaborn as sns
sns.set()

# %%
# %matplotlib inline

# %%
def fullprint(*args, **kwargs):
    np.set_printoptions(threshold=np.inf)
    print(args[0])
    np.set_printoptions(threshold=1000)

# %%
data = pd.read_csv('./commodity_trade_statistics_data.csv')
# Out:
# /Users/mihailojoksimovic/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   country_or_area  year comm_code  \
# 0     Afghanistan  2016     10410
# 1     Afghanistan  2016     10420
# 2     Afghanistan  2008     10210
# 3         Albania  2016     10290
# 4         Albania  2016     10392
#
#                                          commodity    flow  trade_usd  \
# 0                                      Sheep, live  Export       6088
# 1                                      Goats, live  Export       3958
# 2          Bovine animals, live pure-bred breeding  Import    1026804
# 3  Bovine animals, live, except pure-bred breeding  Import    2414533
# 4    Swine, live except pure-bred breeding > 50 kg  Import   14265937
#
#    weight_kg    quantity_name  quantity         category
# 0     2339.0  Number of items      51.0  01_live_animals
# 1      984.0  Number of items      53.0  01_live_animals
# 2      272.0  Number of items    3769.0  01_live_animals
# 3  1114023.0  Number of items    6853.0  01_live_animals
# 4  9484953.0  Number of items   96040.0  01_live_animals

# %%
np.get_printoptions()
# Out:
# {'edgeitems': 3,
#  'formatter': None,
#  'infstr': 'inf',
#  'linewidth': 75,
#  'nanstr': 'nan',
#  'precision': 8,
#  'suppress': False,
#  'threshold': 1000}

# %%
#fullprint(np.sort(data['commodity'].unique()))

# %%
len(data['commodity'].unique())
# Out:
# 5031

# %%
#fullprint(data['country_or_area'].unique())

# %%
data[data['country_or_area'] == 'Serbia']['year'].unique()
# Out:
# array([2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006,
#        2005])

# %%
serbia = data[data['country_or_area'] == 'Serbia']

# %%
type(serbia)
# Out:
# pandas.core.frame.DataFrame

# %%
type(serbia)
# Out:
# pandas.core.frame.DataFrame

# %%
serbia.year.unique()
# Out:
# array([2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006,
#        2005])

# %%
serbia.commodity.value_counts()
# Out:
# Degreased wool nes, not carded, combed or carbonized     24
# Sauces nes, mixed condiments, mixed seasoning            24
# Carpets of wool or fine animal hair, knotted             24
# Couscous                                                 24
# Animal or vegetable fertilizers, in packs >10 kg         24
# Glues or adhesives, prepared nes, package > 1kg          24
# Cocoa powder, unsweetened                                24
# Fertilizers, mixes, nes                                  24
# Bovine skins, whole, raw                                 24
# Rye                                                      24
# Nickel unwrought, not alloyed                            24
# Tin not alloyed unwrought                                24
# Safety or detonating fuses, detonators, igniters         24
# Articles of apparel & clothing accessories of furskin    24
# Enzymes nes, prepared enzymes nes, except rennet         24
# Chewing gum containing sugar, except medicinal           24
# Inflatable pleasure craft                                24
# Pyrophoric alloys, firelighters, etc                     24
# Transfers (decalcomanias), except vitrifiable            24
# Used postage and revenue stamps, first day covers, et    24
# Sweet biscuits, waffles and wafers                       24
# Tobacco, unmanufactured, not stemmed or stripped         24
# Dog or cat food (retail)                                 24
# Adhesives based on rubber or plastic, package >1 kg      24
# Glues based on starches, or modified starches            24
# Coupling devices, parts for railway rolling stock        24
# Fowls, live domestic < 185 grams                         24
# Cocoa powder, sweetened                                  24
# Brakes except air, parts for railway rolling stock       24
# Paintings/drawings/pastels executed by hand              24
#                                                          ..
# Goat or kid skin leather, tanned or retanned, nes         2
# Coarse animal hair, not carded or combed                  2
# Chem wood pulp, sulphite, non-coniferous, unbleached      2
# Coconut (coir) fibre, raw                                 2
# Sisal and Agave, processed but not spun, tow & waste      2
# Basic slag, in packs >10 kg                               2
# Tungsten ores and concentrates                            2
# Parts and accessories for pipe organs, harmoniums, et     2
# Fine animal hair, not carded or combed                    2
# Coarse animal hair, carded or combed                      1
# Tantalum unwrought, bars, rods simply sintered, scrap     1
# Niobium, tantalum and vanadium ores and concentrates      1
# Mechanisms for musical boxes                              1
# Molybdenum concentrates, roasted                          1
# Gliders, hang gliders                                     1
# Chem wood pulp, soda or sulphate, conifer, unbleached     1
# Coconut (coir) fibre,processed not spun, tow & waste      1
# Pyrethrum, roots containing rotenone, extracts            1
# Floating, submersible drilling or production platform     1
# Abaca fibre, processed but not spun, tow, noils, wast     1
# Titanium ores and concentrates                            1
# Thorium ores and concentrates                             1
# Carpets of wool or hair, woven, not made up, nes          1
# Cotton seed oil-cake and other solid residues             1
# Chem wood pulp, sulphite, coniferous unbleached           1
# Uranium ores and concentrates                             1
# Railway wagons, insulated/refrigerated except tank ca     1
# Raw furskin pieces (e.g. heads, tails, paws)              1
# Coconut or copra oil-cake and other solid residues        1
# Chem wood pulp, soda/sulphate, non-conifer, unbleache     1
# Name: commodity, Length: 670, dtype: int64

# %%
serbia.category.unique()
# Out:
# array(['01_live_animals', '05_products_of_animal_origin_nes',
#        '06_live_trees_plants_bulbs_roots_cut_flowers_etc', '10_cereals',
#        '13_lac_gums_resins_vegetable_saps_and_extracts_nes',
#        '14_vegetable_plaiting_materials_vegetable_products_nes',
#        '17_sugars_and_sugar_confectionery',
#        '18_cocoa_and_cocoa_preparations',
#        '19_cereal_flour_starch_milk_preparations_and_products',
#        '21_miscellaneous_edible_preparations',
#        '23_residues_wastes_of_food_industry_animal_fodder',
#        '24_tobacco_and_manufactured_tobacco_substitutes',
#        '26_ores_slag_and_ash', '31_fertilizers',
#        '35_albuminoids_modified_starches_glues_enzymes',
#        '36_explosives_pyrotechnics_matches_pyrophorics_etc',
#        '41_raw_hides_and_skins_other_than_furskins_and_leather',
#        '43_furskins_and_artificial_fur_manufactures_thereof',
#        '45_cork_and_articles_of_cork',
#        '46_manufactures_of_plaiting_material_basketwork_etc',
#        '47_pulp_of_wood_fibrous_cellulosic_material_waste_etc',
#        '49_printed_books_newspapers_pictures_etc', '50_silk',
#        '51_wool_animal_hair_horsehair_yarn_and_fabric_thereof',
#        '53_vegetable_textile_fibres_nes_paper_yarn_woven_fabri',
#        '57_carpets_and_other_textile_floor_coverings',
#        '59_impregnated_coated_or_laminated_textile_fabric',
#        '60_knitted_or_crocheted_fabric', '65_headgear_and_parts_thereof',
#        '66_umbrellas_walking_sticks_seat_sticks_whips_etc',
#        '67_bird_skin_feathers_artificial_flowers_human_hair',
#        '75_nickel_and_articles_thereof', '78_lead_and_articles_thereof',
#        '79_zinc_and_articles_thereof', '80_tin_and_articles_thereof',
#        '81_other_base_metals_cermets_articles_thereof',
#        '86_railway_tramway_locomotives_rolling_stock_equipmen',
#        '88_aircraft_spacecraft_and_parts_thereof',
#        '89_ships_boats_and_other_floating_structures',
#        '92_musical_instruments_parts_and_accessories',
#        '93_arms_and_ammunition_parts_and_accessories_thereof',
#        '97_works_of_art_collectors_pieces_and_antiques',
#        '99_commodities_not_specified_according_to_kind', 'all_commodities'], dtype=object)

# %%
serbia[serbia['category'] == '01_live_animals']['commodity'].unique()
# Out:
# array(['Horses, live pure-bred breeding',
#        'Horses, live except pure-bred breeding',
#        'Asses, mules and hinnies, live',
#        'Bovine animals, live pure-bred breeding',
#        'Bovine animals, live, except pure-bred breeding',
#        'Swine, live pure-bred breeding',
#        'Swine, live except pure-bred breeding < 50 kg',
#        'Swine, live except pure-bred breeding > 50 kg', 'Sheep, live',
#        'Goats, live', 'Fowls, live domestic < 185 grams',
#        'Poultry, live except domestic fowls, < 185 grams',
#        'Fowls, live domestic > 185 grams',
#        'Poultry, live except domestic fowls, > 185 grams',
#        'Animals, live, except farm animals'], dtype=object)

# %%
data.flow.unique()
# Out:
# array(['Export', 'Import', 'Re-Export', 'Re-Import'], dtype=object)

# %%
# WTF is Re-Export and Re-Import?
# Well, it's not relevant for Serbia ... that's cool

serbia.flow.unique()
# Out:
# array(['Export', 'Import'], dtype=object)

# %%
serbia[serbia['flow'] == 'Export']['category'].value_counts().head(10)
# Out:
# 59_impregnated_coated_or_laminated_textile_fabric         262
# 51_wool_animal_hair_horsehair_yarn_and_fabric_thereof     253
# 31_fertilizers                                            235
# 49_printed_books_newspapers_pictures_etc                  221
# 57_carpets_and_other_textile_floor_coverings              213
# 41_raw_hides_and_skins_other_than_furskins_and_leather    204
# 23_residues_wastes_of_food_industry_animal_fodder         196
# 60_knitted_or_crocheted_fabric                            192
# 92_musical_instruments_parts_and_accessories              191
# 86_railway_tramway_locomotives_rolling_stock_equipmen     189
# Name: category, dtype: int64

# %%
serbia[serbia['flow'] == 'Export']['commodity'].value_counts().head(10)
# Out:
# Vegetable saps and extracts nes                          12
# Knit or crochet fabric of manmade fibres, nes            12
# Aircraft parts nes                                       12
# Whalebone, horns, etc unworked or simply prepared nes    12
# Mats, matting and screens, vegetable plaiting materia    12
# Propellent powders                                       12
# Railway cars nes, open, with sides > 60 cm high          12
# Parts and accessories of revolvers or pistols            12
# Carpets of wool or fine animal hair, tufted              12
# Signal pistols, etc, humane killers, etc                 12
# Name: commodity, dtype: int64

# %%
serbia_export = serbia[serbia['flow'] == 'Export']

# %%
sns.countplot(y="commodity", data=serbia_export, order=serbia_export.commodity.value_counts().iloc[:3].index)

# %%
serbia_export[['commodity', 'year','trade_usd']].sort_values(by='trade_usd', ascending = False)
# Out:
#                                                  commodity  year    trade_usd
# 8224003                                    ALL COMMODITIES  2016  14851777129
# 8224007                                    ALL COMMODITIES  2014  14843348443
# 8224009                                    ALL COMMODITIES  2013  14610779427
# 8224005                                    ALL COMMODITIES  2015  13378933798
# 8224013                                    ALL COMMODITIES  2011  11779477582
# 8224011                                    ALL COMMODITIES  2012  11229030695
# 8224019                                    ALL COMMODITIES  2008  10972082013
# 8224015                                    ALL COMMODITIES  2010   9794515799
# 8224021                                    ALL COMMODITIES  2007   8824700743
# 8224017                                    ALL COMMODITIES  2009   8345076235
# 8224023                                    ALL COMMODITIES  2006   6427891860
# 8224025                                    ALL COMMODITIES  2005   4481781933
# 839015                              Maize except seed corn  2012    532965769
# 838953                              Maize except seed corn  2014    448920443
# 839042                              Maize except seed corn  2011    432124509
# 8215209        Commodities not specified according to kind  2011    391756583
# 838889                              Maize except seed corn  2016    335164992
# 838921                              Maize except seed corn  2015    335162851
# 839071                              Maize except seed corn  2010    312013405
# 1998953                      Cigarettes containing tobacco  2016    277456058
# 839102                              Maize except seed corn  2009    261230876
# 8215199        Commodities not specified according to kind  2016    258891066
# 838974                Wheat except durum wheat, and meslin  2013    241565320
# 1998970                      Cigarettes containing tobacco  2015    216138603
# 8215201        Commodities not specified according to kind  2015    193939947
# 1401198    Refined sugar, in solid form, nes, pure sucrose  2010    184497240
# 839195                              Maize except seed corn  2006    173484498
# 1401113    Refined sugar, in solid form, nes, pure sucrose  2013    170934614
# 1401333    Refined sugar, in solid form, nes, pure sucrose  2005    163497770
# 1401142    Refined sugar, in solid form, nes, pure sucrose  2012    162967760
# ...                                                    ...   ...          ...
# 2173243                               Roasted iron pyrites  2008            9
# 5166847  Warp knit fabric of wool or fine animal hair, nes  2006            8
# 2173255                          Tin ores and concentrates  2008            8
# 1401289                          Fructose, chemically pure  2007            7
# 4479356    Woven fabric, >85% flax, unbleached or bleached  2006            7
# 1999052  Cigarette or pipe tobacco and tobacco substitu...  2010            7
# 6771033  Magnesium raspings/turnings/etc, size graded, ...  2010            6
# 1557997                                      Stuffed pasta  2012            6
# 2173359     Slag and ash nes, including seaweed ash (kelp)  2005            6
# 2173238     Slag and ash nes, including seaweed ash (kelp)  2009            5
# 6771187                           Wire, tungsten (wolfram)  2006            5
# 2679714  Ammonium sulphate-nitrate mix, double salts, p...  2015            4
# 5713567        Bird skins and feathers, articles therefrom  2011            4
# 1401259  Glucose including syrup of 20%-50% dry weight ...  2008            4
# 4891511  Hand made rugs including Kelem,Schumacks,Karam...  2016            4
# 3743481  Tanned or dressed whole furskins and pieces, a...  2009            3
# 4479005  Flax tow, waste including yarn waste, garnette...  2016            3
# 2173207  Waste, scale, dross, slag of iron or steel ind...  2010            2
# 6771054  Chromium, articles thereof, waste or scrap/pow...  2010            2
# 4479278             Yarn of other vegetable textile fibres  2008            2
# 2679766                    Sodium nitrate, in packs >10 kg  2014            2
# 4304388  Woven fabric, carded wool or hair + manmade fi...  2014            2
# 3594621                 Parings and other waste of leather  2010            2
# 2173069  Iron ore, concentrate, not iron pyrites, agglo...  2014            2
# 2173241  Iron ore, concentrate, not iron pyrites, agglo...  2008            2
# 6770924  Chromium, articles thereof, waste or scrap/pow...  2013            1
# 2173180  Iron ore, concentrate, not iron pyrites,unaggl...  2010            1
# 3594618    Chamois (including combination chamois) leather  2010            1
# 2173267  Waste, scale, dross, slag of iron or steel ind...  2008            1
# 3594522    Chamois (including combination chamois) leather  2013            1
#
# [5716 rows x 3 columns]

# %%
# Idea: Reorganize data so that rows are Countries and columns are like [year]_[commodity] and values are ... well
# obviously - values for each commodity for each year

# %%
data.comm_code.iloc[1:3]
# Out:
# 1    10420
# 2    10210
# Name: comm_code, dtype: object

# %%
pd.to_numeric(data.comm_code.unique(), errors = 'coerce')
# Out:
# array([  10410.,   10420.,   10210., ...,  999999.,      nan,      nan])

# %%
data['comm_code_numeric'] = pd.to_numeric(data['comm_code'], errors='coerce')

# %%
data.head(5)
# Out:
#   country_or_area  year comm_code  \
# 0     Afghanistan  2016     10410
# 1     Afghanistan  2016     10420
# 2     Afghanistan  2008     10210
# 3         Albania  2016     10290
# 4         Albania  2016     10392
#
#                                          commodity    flow  trade_usd  \
# 0                                      Sheep, live  Export       6088
# 1                                      Goats, live  Export       3958
# 2          Bovine animals, live pure-bred breeding  Import    1026804
# 3  Bovine animals, live, except pure-bred breeding  Import    2414533
# 4    Swine, live except pure-bred breeding > 50 kg  Import   14265937
#
#    weight_kg    quantity_name  quantity         category  comm_code_numeric
# 0     2339.0  Number of items      51.0  01_live_animals            10410.0
# 1      984.0  Number of items      53.0  01_live_animals            10420.0
# 2      272.0  Number of items    3769.0  01_live_animals            10210.0
# 3  1114023.0  Number of items    6853.0  01_live_animals            10290.0
# 4  9484953.0  Number of items   96040.0  01_live_animals            10392.0

# %%
data[(data['comm_code_numeric'] >= 10000) & (data['comm_code_numeric'] <= 11000)]
# Out:
#       country_or_area  year comm_code  \
# 0         Afghanistan  2016     10410
# 1         Afghanistan  2016     10420
# 2         Afghanistan  2008     10210
# 3             Albania  2016     10290
# 4             Albania  2016     10392
# 5             Albania  2016     10511
# 6             Albania  2016     10511
# 7             Albania  2016     10519
# 8             Albania  2016     10591
# 9             Albania  2016     10599
# 10            Albania  2016     10600
# 11            Albania  2015     10290
# 12            Albania  2015     10391
# 13            Albania  2015     10392
# 14            Albania  2015     10511
# 15            Albania  2015     10519
# 16            Albania  2015     10591
# 17            Albania  2015     10599
# 18            Albania  2015     10600
# 19            Albania  2014     10290
# 20            Albania  2014     10392
# 21            Albania  2014     10410
# 22            Albania  2014     10511
# 23            Albania  2014     10519
# 24            Albania  2014     10591
# 25            Albania  2014     10599
# 26            Albania  2014     10600
# 27            Albania  2013     10119
# 28            Albania  2013     10120
# 29            Albania  2013     10210
# ...               ...   ...       ...
# 56550        Zimbabwe  2000     10511
# 56551        Zimbabwe  2000     10519
# 56552        Zimbabwe  2000     10591
# 56553        Zimbabwe  2000     10599
# 56554        Zimbabwe  2000     10600
# 56555        Zimbabwe  1995     10111
# 56556        Zimbabwe  1995     10111
# 56557        Zimbabwe  1995     10119
# 56558        Zimbabwe  1995     10119
# 56559        Zimbabwe  1995     10120
# 56560        Zimbabwe  1995     10210
# 56561        Zimbabwe  1995     10210
# 56562        Zimbabwe  1995     10290
# 56563        Zimbabwe  1995     10290
# 56564        Zimbabwe  1995     10310
# 56565        Zimbabwe  1995     10310
# 56566        Zimbabwe  1995     10391
# 56567        Zimbabwe  1995     10410
# 56568        Zimbabwe  1995     10410
# 56569        Zimbabwe  1995     10420
# 56570        Zimbabwe  1995     10420
# 56571        Zimbabwe  1995     10511
# 56572        Zimbabwe  1995     10511
# 56573        Zimbabwe  1995     10519
# 56574        Zimbabwe  1995     10519
# 56575        Zimbabwe  1995     10591
# 56576        Zimbabwe  1995     10599
# 56577        Zimbabwe  1995     10599
# 56578        Zimbabwe  1995     10600
# 56579        Zimbabwe  1995     10600
#
#                                               commodity    flow  trade_usd  \
# 0                                           Sheep, live  Export       6088
# 1                                           Goats, live  Export       3958
# 2               Bovine animals, live pure-bred breeding  Import    1026804
# 3       Bovine animals, live, except pure-bred breeding  Import    2414533
# 4         Swine, live except pure-bred breeding > 50 kg  Import   14265937
# 5                      Fowls, live domestic < 185 grams  Import    2671732
# 6                      Fowls, live domestic < 185 grams  Export      87581
# 7      Poultry, live except domestic fowls, < 185 grams  Import      26485
# 8                      Fowls, live domestic > 185 grams  Import    2421513
# 9      Poultry, live except domestic fowls, > 185 grams  Import     251318
# 10                   Animals, live, except farm animals  Export     584025
# 11      Bovine animals, live, except pure-bred breeding  Import    7264642
# 12        Swine, live except pure-bred breeding < 50 kg  Import      45843
# 13        Swine, live except pure-bred breeding > 50 kg  Import   14031292
# 14                     Fowls, live domestic < 185 grams  Import    2357680
# 15     Poultry, live except domestic fowls, < 185 grams  Import      32327
# 16                     Fowls, live domestic > 185 grams  Import    2453360
# 17     Poultry, live except domestic fowls, > 185 grams  Import     300813
# 18                   Animals, live, except farm animals  Export     636184
# 19      Bovine animals, live, except pure-bred breeding  Import    8158583
# 20        Swine, live except pure-bred breeding > 50 kg  Import   13483939
# 21                                          Sheep, live  Import      21633
# 22                     Fowls, live domestic < 185 grams  Import    2618381
# 23     Poultry, live except domestic fowls, < 185 grams  Import      31586
# 24                     Fowls, live domestic > 185 grams  Import    3722428
# 25     Poultry, live except domestic fowls, > 185 grams  Import     306678
# 26                   Animals, live, except farm animals  Import      17544
# 27               Horses, live except pure-bred breeding  Import       3598
# 28                       Asses, mules and hinnies, live  Import       6760
# 29              Bovine animals, live pure-bred breeding  Import     153667
# ...                                                 ...     ...        ...
# 56550                  Fowls, live domestic < 185 grams  Export    2360510
# 56551  Poultry, live except domestic fowls, < 185 grams  Export      20017
# 56552                  Fowls, live domestic > 185 grams  Export      18706
# 56553  Poultry, live except domestic fowls, > 185 grams  Export         94
# 56554                Animals, live, except farm animals  Export      43788
# 56555                   Horses, live pure-bred breeding  Import      49216
# 56556                   Horses, live pure-bred breeding  Export      68764
# 56557            Horses, live except pure-bred breeding  Import      48739
# 56558            Horses, live except pure-bred breeding  Export      18941
# 56559                    Asses, mules and hinnies, live  Export       5039
# 56560           Bovine animals, live pure-bred breeding  Import     145814
# 56561           Bovine animals, live pure-bred breeding  Export     692788
# 56562   Bovine animals, live, except pure-bred breeding  Import       4952
# 56563   Bovine animals, live, except pure-bred breeding  Export    4033678
# 56564                    Swine, live pure-bred breeding  Import      27715
# 56565                    Swine, live pure-bred breeding  Export       3785
# 56566     Swine, live except pure-bred breeding < 50 kg  Import      18623
# 56567                                       Sheep, live  Import       8254
# 56568                                       Sheep, live  Export      53576
# 56569                                       Goats, live  Import        629
# 56570                                       Goats, live  Export     417860
# 56571                  Fowls, live domestic < 185 grams  Import     297462
# 56572                  Fowls, live domestic < 185 grams  Export    2204451
# 56573  Poultry, live except domestic fowls, < 185 grams  Import       4671
# 56574  Poultry, live except domestic fowls, < 185 grams  Export       5652
# 56575                  Fowls, live domestic > 185 grams  Export        444
# 56576  Poultry, live except domestic fowls, > 185 grams  Import      25541
# 56577  Poultry, live except domestic fowls, > 185 grams  Export    3482722
# 56578                Animals, live, except farm animals  Import     111642
# 56579                Animals, live, except farm animals  Export    3634957
#
#        weight_kg        quantity_name    quantity         category  \
# 0         2339.0      Number of items        51.0  01_live_animals
# 1          984.0      Number of items        53.0  01_live_animals
# 2          272.0      Number of items      3769.0  01_live_animals
# 3      1114023.0      Number of items      6853.0  01_live_animals
# 4      9484953.0      Number of items     96040.0  01_live_animals
# 5       254652.0      Number of items   5629138.0  01_live_animals
# 6         5320.0      Number of items    115180.0  01_live_animals
# 7         2908.0      Number of items     64000.0  01_live_animals
# 8      1926850.0      Number of items   1006990.0  01_live_animals
# 9       211177.0      Number of items    205124.0  01_live_animals
# 10       59521.0      Number of items     59521.0  01_live_animals
# 11     3519352.0      Number of items     18641.0  01_live_animals
# 12       29930.0      Number of items       795.0  01_live_animals
# 13     9439974.0      Number of items     93222.0  01_live_animals
# 14      264599.0      Number of items   4995885.0  01_live_animals
# 15        3843.0      Number of items     80880.0  01_live_animals
# 16     2133310.0      Number of items   1169944.0  01_live_animals
# 17      258566.0      Number of items  48170912.0  01_live_animals
# 18       80774.0      Number of items     80694.0  01_live_animals
# 19     4080294.0      Number of items     18688.0  01_live_animals
# 20     8113086.0      Number of items     83900.0  01_live_animals
# 21        8125.0      Number of items       257.0  01_live_animals
# 22      209999.0      Number of items   4641445.0  01_live_animals
# 23        3511.0      Number of items     64700.0  01_live_animals
# 24     2715750.0      Number of items   1531017.0  01_live_animals
# 25      217640.0      Number of items    245750.0  01_live_animals
# 26        4948.0          No Quantity         NaN  01_live_animals
# 27        1500.0      Number of items         4.0  01_live_animals
# 28        2250.0      Number of items         5.0  01_live_animals
# 29       62050.0      Number of items       161.0  01_live_animals
# ...          ...                  ...         ...              ...
# 56550   233943.0  Weight in kilograms    233943.0  01_live_animals
# 56551      471.0  Weight in kilograms       471.0  01_live_animals
# 56552    15655.0  Weight in kilograms     15655.0  01_live_animals
# 56553        4.0  Weight in kilograms         4.0  01_live_animals
# 56554     3174.0  Weight in kilograms      3174.0  01_live_animals
# 56555        0.0      Number of items        47.0  01_live_animals
# 56556        0.0      Number of items        48.0  01_live_animals
# 56557        0.0      Number of items        69.0  01_live_animals
# 56558        0.0      Number of items        72.0  01_live_animals
# 56559        0.0      Number of items        89.0  01_live_animals
# 56560        0.0      Number of items     15043.0  01_live_animals
# 56561        0.0      Number of items      1155.0  01_live_animals
# 56562        0.0      Number of items         5.0  01_live_animals
# 56563        0.0      Number of items      8298.0  01_live_animals
# 56564        0.0      Number of items       163.0  01_live_animals
# 56565        0.0      Number of items       912.0  01_live_animals
# 56566        0.0      Number of items        18.0  01_live_animals
# 56567        0.0      Number of items         9.0  01_live_animals
# 56568        0.0      Number of items       245.0  01_live_animals
# 56569        0.0      Number of items         5.0  01_live_animals
# 56570        0.0      Number of items     10975.0  01_live_animals
# 56571        0.0      Number of items    479498.0  01_live_animals
# 56572        0.0      Number of items   7171075.0  01_live_animals
# 56573        0.0      Number of items      1000.0  01_live_animals
# 56574        0.0      Number of items     16120.0  01_live_animals
# 56575        0.0      Number of items      1920.0  01_live_animals
# 56576        0.0      Number of items      1690.0  01_live_animals
# 56577        0.0      Number of items   1005516.0  01_live_animals
# 56578        0.0      Number of items      2381.0  01_live_animals
# 56579        0.0      Number of items     14826.0  01_live_animals
#
#        comm_code_numeric
# 0                10410.0
# 1                10420.0
# 2                10210.0
# 3                10290.0
# 4                10392.0
# 5                10511.0
# 6                10511.0
# 7                10519.0
# 8                10591.0
# 9                10599.0
# 10               10600.0
# 11               10290.0
# 12               10391.0
# 13               10392.0
# 14               10511.0
# 15               10519.0
# 16               10591.0
# 17               10599.0
# 18               10600.0
# 19               10290.0
# 20               10392.0
# 21               10410.0
# 22               10511.0
# 23               10519.0
# 24               10591.0
# 25               10599.0
# 26               10600.0
# 27               10119.0
# 28               10120.0
# 29               10210.0
# ...                  ...
# 56550            10511.0
# 56551            10519.0
# 56552            10591.0
# 56553            10599.0
# 56554            10600.0
# 56555            10111.0
# 56556            10111.0
# 56557            10119.0
# 56558            10119.0
# 56559            10120.0
# 56560            10210.0
# 56561            10210.0
# 56562            10290.0
# 56563            10290.0
# 56564            10310.0
# 56565            10310.0
# 56566            10391.0
# 56567            10410.0
# 56568            10410.0
# 56569            10420.0
# 56570            10420.0
# 56571            10511.0
# 56572            10511.0
# 56573            10519.0
# 56574            10519.0
# 56575            10591.0
# 56576            10599.0
# 56577            10599.0
# 56578            10600.0
# 56579            10600.0
#
# [56580 rows x 11 columns]

# %%
data[round(data['comm_code_numeric'] / 10000) == 1].commodity.unique()
# Out:
# array(['Sheep, live', 'Goats, live',
#        'Bovine animals, live pure-bred breeding',
#        'Bovine animals, live, except pure-bred breeding',
#        'Swine, live except pure-bred breeding > 50 kg',
#        'Fowls, live domestic < 185 grams',
#        'Poultry, live except domestic fowls, < 185 grams',
#        'Fowls, live domestic > 185 grams',
#        'Poultry, live except domestic fowls, > 185 grams',
#        'Animals, live, except farm animals',
#        'Swine, live except pure-bred breeding < 50 kg',
#        'Horses, live except pure-bred breeding',
#        'Asses, mules and hinnies, live', 'Swine, live pure-bred breeding',
#        'Horses, live pure-bred breeding'], dtype=object)

# %%
data[round(data['comm_code_numeric'] / 10000) == 2].commodity.unique()
# Out:
# array(['Goat meat, fresh, chilled or frozen',
#        'Bovine carcasses and half carcasses, frozen',
#        'Bovine cuts bone in, fresh or chilled',
#        'Bovine cuts boneless, fresh or chilled',
#        'Bovine cuts boneless, frozen',
#        'Swine hams, shoulders & cuts bone in, fresh or chille',
#        'Hams, shoulders and cuts, of swine, bone in, frozen',
#        'Swine cuts, frozen nes', 'Bovine edible offal, fresh or chilled',
#        'Bovine livers, frozen',
#        'Bovine edible offal, frozen except livers and tongues',
#        'Swine edible offal, frozen except livers',
#        'Fowls, domestic, whole, frozen',
#        'Poultry cuts & offal, except livers, fresh or chilled',
#        'Fowl cuts & offal, domestic, except livers, frozen',
#        'Turkey cuts & offal, except livers, frozen',
#        'Rabbit or hare meat, offal, fresh, chilled or frozen',
#        'Meat and edible offal nes fresh, chilled or frozen',
#        'Pig and poultry fat, unrendered',
#        'Hams and shoulders, swine, salted, dried or smoked',
#        'Bellies (streaky) of swine, salted, dried or smoked',
#        'Swine meat, salted/dried/smoked not ham/shoulder/bell',
#        'Bovine meat salted, dried or smoked',
#        'Bovine cuts bone in, frozen',
#        'Swine carcasses and half carcasses, fresh or chilled',
#        'Swine cuts, fresh or chilled, nes',
#        'Swine carcasses and half carcasses, frozen',
#        'Lamb carcasses and half carcasses, frozen',
#        'Sheep carcasses and half carcasses, frozen',
#        'Sheep cuts, bone in, frozen', 'Sheep cuts, boneless, frozen',
#        'Horse, ass, mule, hinny meat, fresh, chilled or froze',
#        'Swine edible offal, fresh or chilled', 'Swine livers, frozen',
#        'Sheep, goat, ass, mule, hinnie edible offal, frozen',
#        'Poultry, domestic, whole, fresh or chilled',
#        'Ducks, geese and guinea fowls, domestic, whole, froze',
#        'Fatty livers (geese,ducks) domestic fresh or chilled',
#        'Duck, goose, guinea fowl cuts, offal not liver, froze',
#        'Sheep cuts, bone in, fresh or chilled',
#        'Sheep cuts, boneless, fresh or chilled', 'Bovine tongues, frozen',
#        'Sheep, goat, ass, mule, hinnie offal, fresh or chille',
#        'Meat and edible meat offal cured, flours, meals nes',
#        'Bovine carcasses and half carcasses, fresh or chilled',
#        'Lamb carcasses and half carcasses, fresh or chilled',
#        'Turkeys, domestic, whole, frozen',
#        'Sheep carcasses and half carcasses, fresh or chilled',
#        'Frog legs, fresh, chilled or frozen',
#        'Poultry livers, domestic, frozen'], dtype=object)

# %%
data[round(data['comm_code_numeric'] / 10000) == 3].commodity.unique()
# Out:
# array(['Trout, fresh or chilled, whole',
#        'Fish live, except trout, eel or carp',
#        'Salmon fresh or chilled, whole',
#        'Salmonidae, not trout or salmon,fresh or chilled whol',
#        'Sardines,brisling,sprats, fresh or chilled, whole',
#        'Fish nes, fresh or chilled, whole',
#        'Fish livers and roes, fresh or chilled',
#        'Salmon Atlantic or Danube, frozen, whole',
#        'Fish nes, frozen, whole', 'Fish fillets, frozen',
#        'Fish meat & mince, except liver, roe & fillets, froze',
#        'Fish fillets, dried, salted or in brine, not smoked',
#        'Salmon, smoked, including fillets',
#        'Anchovies, salted or in brine, not dried or smoked',
#        'Shrimps and prawns, frozen', 'Crustaceans nes, not frozen',
#        'Cuttle fish, squid, frozen, dried, salted or in brine',
#        'Octopus, frozen, dried, salted or in brine',
#        'Snails, edible (except sea snails)',
#        'Herring, fresh or chilled, whole', 'Sole, frozen, whole',
#        'Cuttle fish, squid, live, fresh or chilled', 'Trout, live',
#        'Carp, live',
#        'Flatfish, fresh/chilled not halibut/plaice/sole, whol',
#        'Cod, fresh or chilled, whole', 'Mackerel, fresh or chilled, whole',
#        'Eels, fresh or chilled, whole', 'Trout, frozen, whole',
#        'Salmonidae, nes,frozen, whole',
#        'Flatfish except halibut, plaice or sole, frozen, whol',
#        'Skipjack,stripe-bellied bonito, frozen, whole',
#        'Sardines,brisling,sprats, frozen, whole',
#        'Mackerel, frozen, whole',
#        'Dogfish and other sharks, frozen, whole',
#        'Sea bass, frozen, whole',
#        'Fish fillet or meat, fresh or chilled, not liver, roe',
#        'Livers and roes, dried, smoked, salted or in brine',
#        'Smoked fish & fillets other than herrings or salmon',
#        'Dried fish, other than cod, not smoked',
#        'Fish nes, salted or in brine, not dried or smoked',
#        'Rock lobster and other sea crawfish, frozen',
#        'Lobsters (Homarus) frozen', 'Crabs, frozen',
#        'Crustaceans nes, frozen,', 'Lobsters (Homarus), not frozen',
#        'Shrimps and prawns, not frozen', 'Oysters',
#        'Scallops other than live, fresh or chilled',
#        'Mussels, shelled or not, live, fresh or chilled',
#        'Mussels, frozen, dried, salted or in brine',
#        'Aquatic invertebrates nes, frozen or preserved',
#        'Halibut, fresh or chilled, whole',
#        'Plaice, fresh or chilled, whole',
#        'Tuna nes, fresh or chilled, whole',
#        'Haddock, fresh or chilled, whole',
#        'Salmon, Pacific, frozen, whole', 'Plaice, frozen, whole',
#        'Tunas(yellowfin) frozen, whole', 'Herrings, frozen, whole',
#        'Cod, frozen, whole', 'Haddock, frozen, whole',
#        'Hake, frozen, whole', 'Crabs, not frozen',
#        'Aquatic invertebrates nes, fresh or chilled, live',
#        'Ornamental fish, live', 'Fish livers and roes, frozen',
#        'Tuna(albacore,longfin) fresh or chilled, whole',
#        'Dogfish and other sharks, fresh or chilled, whole',
#        'Tunas nes, frozen, whole', 'Octopus, live, fresh or chilled',
#        'Eels, live', 'Tuna(yellowfin) fresh or chilled, whole',
#        'Eels, frozen, whole', 'Scallops, live, fresh or chilled',
#        'Herrings, smoked, including fillets',
#        'Cod dried, whether or not salted but not smoked',
#        'Sole, fresh or chilled, whole', 'Halibut, frozen, whole',
#        'Tunas(albacore,longfin), frozen, whole',
#        'Flours, meals & pellets of fish for human consumption',
#        'Rock lobster and other sea crawfish not frozen',
#        'Coalfish, fresh or chilled, whole',
#        'Skipjack,stripe-belly bonito, fresh or chilled, whole',
#        'Cod, salted or in brine, not dried or smoked',
#        'Coalfish, frozen, whole',
#        'Herrings, salted or in brine, not dried or smoked'], dtype=object)

# %%
data[round(data['comm_code_numeric'] / 10000) == 3]
# Out:
#        country_or_area  year comm_code  \
# 156580     Afghanistan  2010     30211
# 156581         Albania  2016     30199
# 156582         Albania  2016     30211
# 156583         Albania  2016     30212
# 156584         Albania  2016     30212
# 156585         Albania  2016     30219
# 156586         Albania  2016     30219
# 156587         Albania  2016     30261
# 156588         Albania  2016     30269
# 156589         Albania  2016     30269
# 156590         Albania  2016     30270
# 156591         Albania  2016     30322
# 156592         Albania  2016     30379
# 156593         Albania  2016     30379
# 156594         Albania  2016     30420
# 156595         Albania  2016     30490
# 156596         Albania  2016     30530
# 156597         Albania  2016     30541
# 156598         Albania  2016     30563
# 156599         Albania  2016     30563
# 156600         Albania  2016     30613
# 156601         Albania  2016     30613
# 156602         Albania  2016     30629
# 156603         Albania  2016     30749
# 156604         Albania  2016     30749
# 156605         Albania  2016     30759
# 156606         Albania  2016     30760
# 156607         Albania  2015     30199
# 156608         Albania  2015     30212
# 156609         Albania  2015     30212
# ...                ...   ...       ...
# 256550     Faeroe Isds  1999     30614
# 256551     Faeroe Isds  1999     30619
# 256552     Faeroe Isds  1999     30619
# 256553     Faeroe Isds  1999     30621
# 256554     Faeroe Isds  1999     30622
# 256555     Faeroe Isds  1999     30623
# 256556     Faeroe Isds  1999     30624
# 256557     Faeroe Isds  1999     30624
# 256558     Faeroe Isds  1999     30629
# 256559     Faeroe Isds  1999     30629
# 256560     Faeroe Isds  1999     30721
# 256561     Faeroe Isds  1999     30729
# 256562     Faeroe Isds  1999     30729
# 256563     Faeroe Isds  1999     30739
# 256564     Faeroe Isds  1999     30741
# 256565     Faeroe Isds  1999     30749
# 256566     Faeroe Isds  1999     30749
# 256567     Faeroe Isds  1999     30751
# 256568     Faeroe Isds  1999     30751
# 256569     Faeroe Isds  1999     30759
# 256570     Faeroe Isds  1999     30760
# 256571     Faeroe Isds  1999     30791
# 256572     Faeroe Isds  1999     30799
# 256573     Faeroe Isds  1998     30110
# 256574     Faeroe Isds  1998     30199
# 256575     Faeroe Isds  1998     30211
# 256576     Faeroe Isds  1998     30212
# 256577     Faeroe Isds  1998     30219
# 256578     Faeroe Isds  1998     30221
# 256579     Faeroe Isds  1998     30221
#
#                                                 commodity    flow  trade_usd  \
# 156580                     Trout, fresh or chilled, whole  Import       8600
# 156581               Fish live, except trout, eel or carp  Import    2202944
# 156582                     Trout, fresh or chilled, whole  Export    1973381
# 156583                     Salmon fresh or chilled, whole  Import     387938
# 156584                     Salmon fresh or chilled, whole  Export      39162
# 156585  Salmonidae, not trout or salmon,fresh or chill...  Import      70993
# 156586  Salmonidae, not trout or salmon,fresh or chill...  Export      49287
# 156587  Sardines,brisling,sprats, fresh or chilled, whole  Import     305172
# 156588                  Fish nes, fresh or chilled, whole  Import    2654089
# 156589                  Fish nes, fresh or chilled, whole  Export    1353539
# 156590             Fish livers and roes, fresh or chilled  Import       3525
# 156591           Salmon Atlantic or Danube, frozen, whole  Export      22526
# 156592                            Fish nes, frozen, whole  Import    1114294
# 156593                            Fish nes, frozen, whole  Export     631255
# 156594                               Fish fillets, frozen  Export     147044
# 156595  Fish meat & mince, except liver, roe & fillets...  Export     111045
# 156596  Fish fillets, dried, salted or in brine, not s...  Export    7529293
# 156597                  Salmon, smoked, including fillets  Import      14497
# 156598  Anchovies, salted or in brine, not dried or sm...  Import   18934237
# 156599  Anchovies, salted or in brine, not dried or sm...  Export    6112027
# 156600                         Shrimps and prawns, frozen  Import    9012365
# 156601                         Shrimps and prawns, frozen  Export    3555835
# 156602                        Crustaceans nes, not frozen  Export      23304
# 156603  Cuttle fish, squid, frozen, dried, salted or i...  Import    4232617
# 156604  Cuttle fish, squid, frozen, dried, salted or i...  Export    5825686
# 156605         Octopus, frozen, dried, salted or in brine  Import     237215
# 156606                 Snails, edible (except sea snails)  Export    1122874
# 156607               Fish live, except trout, eel or carp  Import     915197
# 156608                     Salmon fresh or chilled, whole  Import     341641
# 156609                     Salmon fresh or chilled, whole  Export      52271
# ...                                                   ...     ...        ...
# 256550                                      Crabs, frozen  Export      12724
# 256551                           Crustaceans nes, frozen,  Import       2227
# 256552                           Crustaceans nes, frozen,  Export     746240
# 256553     Rock lobster and other sea crawfish not frozen  Export       5751
# 256554                     Lobsters (Homarus), not frozen  Export       7446
# 256555                     Shrimps and prawns, not frozen  Import        995
# 256556                                  Crabs, not frozen  Import        329
# 256557                                  Crabs, not frozen  Export          2
# 256558                        Crustaceans nes, not frozen  Import        355
# 256559                        Crustaceans nes, not frozen  Export      73738
# 256560                   Scallops, live, fresh or chilled  Export         32
# 256561         Scallops other than live, fresh or chilled  Import        187
# 256562         Scallops other than live, fresh or chilled  Export    3882404
# 256563         Mussels, frozen, dried, salted or in brine  Import      71710
# 256564         Cuttle fish, squid, live, fresh or chilled  Export      66684
# 256565  Cuttle fish, squid, frozen, dried, salted or i...  Import        226
# 256566  Cuttle fish, squid, frozen, dried, salted or i...  Export       9418
# 256567                    Octopus, live, fresh or chilled  Import     242953
# 256568                    Octopus, live, fresh or chilled  Export      15093
# 256569         Octopus, frozen, dried, salted or in brine  Import    1955142
# 256570                 Snails, edible (except sea snails)  Import       3601
# 256571  Aquatic invertebrates nes, fresh or chilled, live  Export       8337
# 256572     Aquatic invertebrates nes, frozen or preserved  Import       1037
# 256573                              Ornamental fish, live  Import      13058
# 256574               Fish live, except trout, eel or carp  Export       4663
# 256575                     Trout, fresh or chilled, whole  Export    1068602
# 256576                     Salmon fresh or chilled, whole  Export   37944272
# 256577  Salmonidae, not trout or salmon,fresh or chill...  Export     135416
# 256578                   Halibut, fresh or chilled, whole  Import       4621
# 256579                   Halibut, fresh or chilled, whole  Export    3321151
#
#          weight_kg        quantity_name    quantity  \
# 156580      9000.0  Weight in kilograms      9000.0
# 156581     39896.0  Weight in kilograms     39896.0
# 156582    266283.0  Weight in kilograms    266283.0
# 156583     96083.0  Weight in kilograms     96083.0
# 156584      5974.0  Weight in kilograms      5974.0
# 156585     11065.0  Weight in kilograms     11065.0
# 156586     10808.0  Weight in kilograms     10808.0
# 156587    457234.0  Weight in kilograms    457234.0
# 156588   1322338.0  Weight in kilograms   1322338.0
# 156589    241436.0  Weight in kilograms    241436.0
# 156590        51.0  Weight in kilograms        51.0
# 156591      2445.0  Weight in kilograms      2445.0
# 156592    698868.0  Weight in kilograms    698868.0
# 156593    119205.0  Weight in kilograms    119205.0
# 156594     22523.0  Weight in kilograms     22523.0
# 156595     20212.0  Weight in kilograms     20212.0
# 156596    558797.0  Weight in kilograms    558797.0
# 156597       779.0  Weight in kilograms       779.0
# 156598   5799550.0  Weight in kilograms   5799550.0
# 156599    700869.0  Weight in kilograms    700869.0
# 156600   1870995.0  Weight in kilograms   1870995.0
# 156601    375933.0  Weight in kilograms    375933.0
# 156602      1545.0  Weight in kilograms      1545.0
# 156603   1079705.0  Weight in kilograms   1079705.0
# 156604    858843.0  Weight in kilograms    858843.0
# 156605     98260.0  Weight in kilograms     98260.0
# 156606    697820.0  Weight in kilograms    697820.0
# 156607     17469.0  Weight in kilograms     17469.0
# 156608     71879.0  Weight in kilograms     71879.0
# 156609      8600.0  Weight in kilograms      8600.0
# ...            ...                  ...         ...
# 256550       953.0  Weight in kilograms       953.0
# 256551       230.0  Weight in kilograms       230.0
# 256552     81886.0  Weight in kilograms     81886.0
# 256553       425.0  Weight in kilograms       425.0
# 256554       651.0  Weight in kilograms       651.0
# 256555        67.0  Weight in kilograms        67.0
# 256556        48.0  Weight in kilograms        48.0
# 256557        10.0  Weight in kilograms        10.0
# 256558        36.0  Weight in kilograms        36.0
# 256559      6125.0  Weight in kilograms      6125.0
# 256560        20.0  Weight in kilograms        20.0
# 256561        31.0  Weight in kilograms        31.0
# 256562    493717.0  Weight in kilograms    493717.0
# 256563     54782.0  Weight in kilograms     54782.0
# 256564     23062.0  Weight in kilograms     23062.0
# 256565        49.0  Weight in kilograms        49.0
# 256566      5750.0  Weight in kilograms      5750.0
# 256567    204374.0  Weight in kilograms    204374.0
# 256568      5504.0  Weight in kilograms      5504.0
# 256569   1977350.0  Weight in kilograms   1977350.0
# 256570       200.0  Weight in kilograms       200.0
# 256571      1225.0  Weight in kilograms      1225.0
# 256572       100.0  Weight in kilograms       100.0
# 256573       648.0  Weight in kilograms       648.0
# 256574       796.0  Weight in kilograms       796.0
# 256575    381022.0  Weight in kilograms    381022.0
# 256576  11428208.0  Weight in kilograms  11428208.0
# 256577   1026812.0  Weight in kilograms   1026812.0
# 256578       861.0  Weight in kilograms       861.0
# 256579    859656.0  Weight in kilograms    859656.0
#
#                                                  category  comm_code_numeric
# 156580  03_fish_crustaceans_molluscs_aquatic_invertebr...            30211.0
# 156581  03_fish_crustaceans_molluscs_aquatic_invertebr...            30199.0
# 156582  03_fish_crustaceans_molluscs_aquatic_invertebr...            30211.0
# 156583  03_fish_crustaceans_molluscs_aquatic_invertebr...            30212.0
# 156584  03_fish_crustaceans_molluscs_aquatic_invertebr...            30212.0
# 156585  03_fish_crustaceans_molluscs_aquatic_invertebr...            30219.0
# 156586  03_fish_crustaceans_molluscs_aquatic_invertebr...            30219.0
# 156587  03_fish_crustaceans_molluscs_aquatic_invertebr...            30261.0
# 156588  03_fish_crustaceans_molluscs_aquatic_invertebr...            30269.0
# 156589  03_fish_crustaceans_molluscs_aquatic_invertebr...            30269.0
# 156590  03_fish_crustaceans_molluscs_aquatic_invertebr...            30270.0
# 156591  03_fish_crustaceans_molluscs_aquatic_invertebr...            30322.0
# 156592  03_fish_crustaceans_molluscs_aquatic_invertebr...            30379.0
# 156593  03_fish_crustaceans_molluscs_aquatic_invertebr...            30379.0
# 156594  03_fish_crustaceans_molluscs_aquatic_invertebr...            30420.0
# 156595  03_fish_crustaceans_molluscs_aquatic_invertebr...            30490.0
# 156596  03_fish_crustaceans_molluscs_aquatic_invertebr...            30530.0
# 156597  03_fish_crustaceans_molluscs_aquatic_invertebr...            30541.0
# 156598  03_fish_crustaceans_molluscs_aquatic_invertebr...            30563.0
# 156599  03_fish_crustaceans_molluscs_aquatic_invertebr...            30563.0
# 156600  03_fish_crustaceans_molluscs_aquatic_invertebr...            30613.0
# 156601  03_fish_crustaceans_molluscs_aquatic_invertebr...            30613.0
# 156602  03_fish_crustaceans_molluscs_aquatic_invertebr...            30629.0
# 156603  03_fish_crustaceans_molluscs_aquatic_invertebr...            30749.0
# 156604  03_fish_crustaceans_molluscs_aquatic_invertebr...            30749.0
# 156605  03_fish_crustaceans_molluscs_aquatic_invertebr...            30759.0
# 156606  03_fish_crustaceans_molluscs_aquatic_invertebr...            30760.0
# 156607  03_fish_crustaceans_molluscs_aquatic_invertebr...            30199.0
# 156608  03_fish_crustaceans_molluscs_aquatic_invertebr...            30212.0
# 156609  03_fish_crustaceans_molluscs_aquatic_invertebr...            30212.0
# ...                                                   ...                ...
# 256550  03_fish_crustaceans_molluscs_aquatic_invertebr...            30614.0
# 256551  03_fish_crustaceans_molluscs_aquatic_invertebr...            30619.0
# 256552  03_fish_crustaceans_molluscs_aquatic_invertebr...            30619.0
# 256553  03_fish_crustaceans_molluscs_aquatic_invertebr...            30621.0
# 256554  03_fish_crustaceans_molluscs_aquatic_invertebr...            30622.0
# 256555  03_fish_crustaceans_molluscs_aquatic_invertebr...            30623.0
# 256556  03_fish_crustaceans_molluscs_aquatic_invertebr...            30624.0
# 256557  03_fish_crustaceans_molluscs_aquatic_invertebr...            30624.0
# 256558  03_fish_crustaceans_molluscs_aquatic_invertebr...            30629.0
# 256559  03_fish_crustaceans_molluscs_aquatic_invertebr...            30629.0
# 256560  03_fish_crustaceans_molluscs_aquatic_invertebr...            30721.0
# 256561  03_fish_crustaceans_molluscs_aquatic_invertebr...            30729.0
# 256562  03_fish_crustaceans_molluscs_aquatic_invertebr...            30729.0
# 256563  03_fish_crustaceans_molluscs_aquatic_invertebr...            30739.0
# 256564  03_fish_crustaceans_molluscs_aquatic_invertebr...            30741.0
# 256565  03_fish_crustaceans_molluscs_aquatic_invertebr...            30749.0
# 256566  03_fish_crustaceans_molluscs_aquatic_invertebr...            30749.0
# 256567  03_fish_crustaceans_molluscs_aquatic_invertebr...            30751.0
# 256568  03_fish_crustaceans_molluscs_aquatic_invertebr...            30751.0
# 256569  03_fish_crustaceans_molluscs_aquatic_invertebr...            30759.0
# 256570  03_fish_crustaceans_molluscs_aquatic_invertebr...            30760.0
# 256571  03_fish_crustaceans_molluscs_aquatic_invertebr...            30791.0
# 256572  03_fish_crustaceans_molluscs_aquatic_invertebr...            30799.0
# 256573  03_fish_crustaceans_molluscs_aquatic_invertebr...            30110.0
# 256574  03_fish_crustaceans_molluscs_aquatic_invertebr...            30199.0
# 256575  03_fish_crustaceans_molluscs_aquatic_invertebr...            30211.0
# 256576  03_fish_crustaceans_molluscs_aquatic_invertebr...            30212.0
# 256577  03_fish_crustaceans_molluscs_aquatic_invertebr...            30219.0
# 256578  03_fish_crustaceans_molluscs_aquatic_invertebr...            30221.0
# 256579  03_fish_crustaceans_molluscs_aquatic_invertebr...            30221.0
#
# [100000 rows x 11 columns]

# %%
data[round(data['comm_code_numeric'] / 10000) == 9].commodity.unique()
# Out:
# array(['Tea, green (unfermented) in packages < 3 kg',
#        'Tea, black (fermented or partly) in packages < 3 kg', 'Mate',
#        'Coriander seeds', 'Cumin seeds', 'Saffron', 'Spices nes',
#        'Coffee, not roasted, not decaffeinated',
#        'Coffee, roasted, not decaffeinated',
#        'Coffee, roasted, decaffeinated',
#        'Coffee substitutes containing coffee',
#        'Tea, green (unfermented) in packages > 3 kg',
#        'Tea, black (fermented or partly) in packages > 3 kg',
#        'Pepper of the genus Piper, whole',
#        'Pepper of the genus Piper, crushed or ground',
#        'Capsicum or Pimenta, dried, crushed or ground', 'Vanilla beans',
#        'Cinnamon and cinnamon-tree flowers whole',
#        'Cinnamon and cinnamon-tree flowers crushed or ground', 'Nutmeg',
#        'Anise or badian seeds', 'Ginger', 'Turmeric (curcuma)',
#        'Mixtures of spices', 'Cloves (whole fruit, cloves and stems)',
#        'Coffee, not roasted, decaffeinated', 'Mace', 'Cardamoms',
#        'Fennel seeds, juniper berries', 'Caraway seeds',
#        'Thyme and bay leaves', 'Curry', 'Coffee husks and skins'], dtype=object)

# %%
data[round(data['comm_code_numeric'] / 10000) == 10].commodity.unique()
# Out:
# array(['Grain sorghum', 'Barley', 'Durum wheat',
#        'Wheat except durum wheat, and meslin', 'Oats', 'Maize (corn) seed',
#        'Maize except seed corn', 'Rice in the husk (paddy or rough)',
#        'Rice, husked (brown)', 'Rice, semi-milled or wholly milled',
#        'Rice, broken', 'Canary seed', 'Rye', 'Buckwheat', 'Millet',
#        'Cereals unmilled nes'], dtype=object)

# %%
pd.Series(data.category.unique()).to_excel('./unique_categories.xlsx')

# %%
pd.Series(data.commodity.unique()).to_excel('./unique_commodities.xlsx')

# %%
# nah ,basically, we can try a DataFrame where Index is == Country name, and columns are [year]_[Specific Category]
# For example -- [year]_01_live_animals and then search for similarities

# %%
#df = pd.DataFrame()

countries_df = pd.DataFrame(index=data.country_or_area.unique())

for i in range(2010, 2017):
    countries_df['year_' + str(i)] = np.nan

# %%
is_export = data['flow'] == 'Export'
is_live_animals = data['category'] == '01_live_animals'
year_filter = data['year'] >= 2010

by_country = data[year_filter & is_export & is_live_animals].groupby(['country_or_area', 'year']).sum().unstack(level=0)

# %%
by_country = data[year_filter & is_export & is_live_animals].groupby(['country_or_area', 'year']).sum()

# %%
by_country.loc['USA']
# Out:
#        trade_usd    weight_kg     quantity  comm_code_numeric
# year
# 2010   814890071   44007732.0   89691483.0           145473.0
# 2011  1038251364  123590865.0   98152074.0           145473.0
# 2012  1189530232  107823832.0  100987174.0           155593.0
# 2013  1019524929   68486365.0  101986883.0           155593.0
# 2014   944407211   17794635.0   76476824.0           155593.0
# 2015   757360691   32782351.0   77871593.0           155593.0
# 2016   784223079    9788757.0   85619694.0           155593.0

# %%
by_country.loc['Afghanistan'].loc[2016]['trade_usd']
# Out:
# 10046.0

# %%
# Ok stao sam kod toga da sam pokusavao da napravim DataFrame kao sto sam gore zamislio --> [year]_01_live_animals

data.head()
# Out:
#   country_or_area  year comm_code  \
# 0     Afghanistan  2016     10410
# 1     Afghanistan  2016     10420
# 2     Afghanistan  2008     10210
# 3         Albania  2016     10290
# 4         Albania  2016     10392
#
#                                          commodity    flow  trade_usd  \
# 0                                      Sheep, live  Export       6088
# 1                                      Goats, live  Export       3958
# 2          Bovine animals, live pure-bred breeding  Import    1026804
# 3  Bovine animals, live, except pure-bred breeding  Import    2414533
# 4    Swine, live except pure-bred breeding > 50 kg  Import   14265937
#
#    weight_kg    quantity_name  quantity         category  comm_code_numeric
# 0     2339.0  Number of items      51.0  01_live_animals            10410.0
# 1      984.0  Number of items      53.0  01_live_animals            10420.0
# 2      272.0  Number of items    3769.0  01_live_animals            10210.0
# 3  1114023.0  Number of items    6853.0  01_live_animals            10290.0
# 4  9484953.0  Number of items   96040.0  01_live_animals            10392.0

# %%
countries_df = pd.DataFrame(index=data.country_or_area.unique())

for i in range(2010, 2017):
    countries_df['year_' + str(i)] = np.nan

# %%
for year in range(2010, 2017):
    for country in countries_df.index:
#         trade_usd = grouped_countries.loc[country].loc[year]

        try:
#             trade_usd = by_country.loc[year]['trade_usd'].loc[country]
            trade_usd = by_country.loc[country].loc[year]['trade_usd']
    
            #print("In year " + str(year) + " country " + country +" had trade_usd: " + str(trade_usd))
        
            countries_df.loc[country]['year_'+str(year)] = trade_usd
        except:
            pass

# %%
countries_df.head()
# Out:
#              year_2010  year_2011  year_2012  year_2013  year_2014  year_2015  \
# Afghanistan        NaN        NaN        NaN        NaN        NaN        NaN
# Albania       609694.0   997424.0   901217.0   846588.0        NaN   636184.0
# Algeria         4396.0        NaN   153141.0    14163.0    20466.0    86724.0
# Andorra        93535.0    68199.0    37857.0    60296.0   200316.0        NaN
# Angola             NaN        NaN        NaN        NaN        NaN        NaN
#
#              year_2016
# Afghanistan    10046.0
# Albania       671606.0
# Algeria       126400.0
# Andorra            NaN
# Angola             NaN

# %%
data[(data['country_or_area'] == 'Afghanistan') & (data['year'] == 2016) & (data['flow'] == 'Export') & (data['category'] == '01_live_animals')]
# Out:
#   country_or_area  year comm_code    commodity    flow  trade_usd  weight_kg  \
# 0     Afghanistan  2016     10410  Sheep, live  Export       6088     2339.0
# 1     Afghanistan  2016     10420  Goats, live  Export       3958      984.0
#
#      quantity_name  quantity         category  comm_code_numeric
# 0  Number of items      51.0  01_live_animals            10410.0
# 1  Number of items      53.0  01_live_animals            10420.0

# %% [markdown]
# # Predictions

# %%
clean_prediction_data = countries_df.dropna()

# %%
countries_df['cluster'] = np.nan

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(clean_prediction_data)

y_kmeans = kmeans.predict(clean_prediction_data)

# %%
i = 0

for country in clean_prediction_data.index:
    cluster = y_kmeans[i]
    #print(str(i) + " " + country + " Cluster: " + str(cluster))
    countries_df.loc[country]['cluster'] = cluster
    i += 1

# %%
countries_df[countries_df['cluster'] == 2.0]
# Out:
#                    year_2010     year_2011     year_2012     year_2013  \
# Australia       1.052354e+09  1.106495e+09  1.084098e+09  1.007219e+09
# Belgium         5.041189e+08  5.304999e+08  5.138012e+08  6.279661e+08
# Brazil          6.972779e+08  4.916599e+08  6.425674e+08  7.825979e+08
# China           4.539627e+08  5.707983e+08  5.828659e+08  5.806246e+08
# Denmark         8.639078e+08  9.102473e+08  1.178110e+09  1.246174e+09
# Ireland         4.486982e+08  4.970093e+08  4.233313e+08  5.834600e+08
# Mexico          5.424061e+08  6.348336e+08  7.546680e+08  5.430526e+08
# Spain           4.533614e+08  5.218888e+08  5.810682e+08  6.357624e+08
# United Kingdom  5.841416e+08  6.456352e+08  5.780961e+08  6.182577e+08
# USA             8.148901e+08  1.038251e+09  1.189530e+09  1.019525e+09
#
#                    year_2014     year_2015     year_2016  cluster
# Australia       1.460544e+09  1.423882e+09  1.398836e+09      2.0
# Belgium         5.834046e+08  4.825554e+08  5.269865e+08      2.0
# Brazil          7.421993e+08  2.781561e+08  2.837528e+08      2.0
# China           5.855724e+08  5.977307e+08  6.467382e+08      2.0
# Denmark         1.312477e+09  1.016614e+09  1.148401e+09      2.0
# Ireland         5.282109e+08  4.774764e+08  3.758895e+08      2.0
# Mexico          7.724136e+08  8.808892e+08  6.610378e+08      2.0
# Spain           6.432300e+08  6.493000e+08  6.933758e+08      2.0
# United Kingdom  6.690219e+08  6.748947e+08  6.800278e+08      2.0
# USA             9.444072e+08  7.573607e+08  7.842231e+08      2.0

# %%
countries_df[countries_df['cluster'] == 1.0]
# Out:
#                 year_2010     year_2011     year_2012     year_2013  \
# Canada       1.626397e+09  1.435682e+09  1.621261e+09  1.824440e+09
# France       2.286582e+09  2.651017e+09  2.490415e+09  2.435325e+09
# Germany      1.270508e+09  1.647555e+09  1.746768e+09  1.800066e+09
# Netherlands  2.092791e+09  2.620172e+09  2.638863e+09  2.978823e+09
#
#                 year_2014     year_2015     year_2016  cluster
# Canada       2.445299e+09  1.916830e+09  1.613712e+09      1.0
# France       2.413288e+09  2.216184e+09  2.152628e+09      1.0
# Germany      1.772561e+09  1.468941e+09  1.297583e+09      1.0
# Netherlands  2.653795e+09  2.121732e+09  2.312945e+09      1.0

# %%
countries_df[countries_df['cluster'] == 0.0]
# Out:
#                            year_2010    year_2011    year_2012    year_2013  \
# Antigua and Barbuda         241520.0      26378.0       6575.0      12513.0
# Argentina                 25658396.0   22449517.0   26089160.0   17886305.0
# Aruba                        25778.0      26645.0     118341.0     103243.0
# Bahrain                     697101.0      39308.0     146864.0    1141889.0
# Barbados                    814037.0    1408185.0     858163.0     831149.0
# Belarus                   14609600.0   32095100.0   26897900.0   11278100.0
# Belgium                  504118948.0  530499861.0  513801224.0  627966107.0
# Bosnia Herzegovina         5106611.0    4905123.0    3850376.0    4368161.0
# Botswana                     24432.0   10704234.0    3019807.0    4860191.0
# Brazil                   697277863.0  491659908.0  642567351.0  782597941.0
# Bulgaria                  45135525.0   93392570.0   33349272.0   24862251.0
# Cambodia                     97937.0     406878.0     257371.0      55101.0
# Chile                     11480228.0    7460181.0    6882324.0    6490266.0
# China                    453962708.0  570798288.0  582865896.0  580624579.0
# China, Hong Kong SAR        566784.0     503200.0    2005508.0    1248543.0
# Colombia                  22202018.0   43660679.0  353972502.0  294087089.0
# Costa Rica                 4829302.0    6945164.0    5741083.0    4039158.0
# Croatia                   20948560.0   51472568.0   59518626.0   62331789.0
# Cyprus                     1002484.0    1436276.0    2164415.0    2941349.0
# Czech Rep.               231828797.0  326313028.0  356624111.0  374762450.0
# Dominican Rep.             2220206.0    3997307.0    4598688.0    6160358.0
# Ecuador                     241948.0     359064.0     490594.0     724759.0
# Egypt                     15034789.0   12583607.0   16355101.0   18074673.0
# El Salvador                8585365.0   10008362.0    9024529.0   11495683.0
# Estonia                   37775459.0   60843103.0   40170332.0   45141530.0
# Ethiopia                 132424459.0  190357050.0  181926964.0  340858615.0
# Finland                    7757509.0    9018199.0    9698993.0    5850814.0
# Georgia                   14268386.0   15204529.0   58081955.0   63185211.0
# Greece                    14536430.0   40873908.0   24958724.0   16440294.0
# Guyana                      949702.0     823026.0    1001538.0    1239410.0
# ...                              ...          ...          ...          ...
# Oman                      58783069.0   44356142.0   41265489.0   57160133.0
# Other Asia, nes            4117152.0    3633926.0    3490720.0    4203290.0
# Pakistan                  26409892.0   22940882.0   16328499.0   17516187.0
# Paraguay                    132396.0      60965.0      28053.0      10782.0
# Peru                       7781592.0    7962539.0    8927353.0   10317525.0
# Philippines                5015484.0    5805356.0   13919408.0   19199162.0
# Poland                   265614779.0  249975479.0  240206491.0  239125153.0
# Portugal                  96330515.0   98027535.0  115992721.0  126350807.0
# Rep. of Korea              1799043.0    1721285.0    1539152.0    1637942.0
# Rep. of Moldova           11237532.0    8169647.0    8721661.0    7174910.0
# Romania                  248625911.0  318321594.0  379530461.0  400396206.0
# Russian Federation         4739409.0    6698028.0   11549491.0   16393180.0
# Rwanda                     4025740.0    5918897.0    8063437.0    7952824.0
# Senegal                     272687.0     158965.0     227880.0     370994.0
# Serbia                    66578524.0    8851653.0   59307088.0   47394048.0
# Seychelles                  100391.0     103425.0     166328.0     128947.0
# Singapore                  8970890.0    8111397.0    5429530.0    9809332.0
# Slovakia                 166293268.0  229470388.0  263849712.0  306018106.0
# South Africa              54834432.0   49304463.0   52226238.0   49632064.0
# Spain                    453361440.0  521888780.0  581068240.0  635762421.0
# Sri Lanka                   323549.0     276715.0     420713.0     296035.0
# Sweden                    19230247.0   19933971.0   30075407.0   25660308.0
# Switzerland               11951408.0   16923778.0   12401074.0   37743104.0
# TFYR of Macedonia          4059484.0    4235178.0    3739894.0    2342060.0
# Tunisia                     446093.0     474434.0    1225917.0    1587025.0
# Turkey                     7322183.0    6214947.0    8142136.0   13463929.0
# United Kingdom           584141559.0  645635168.0  578096128.0  618257676.0
# United Rep. of Tanzania     652884.0     567466.0     338816.0    1126142.0
# Uruguay                  140659251.0  163430024.0   86988891.0   37024821.0
# Zimbabwe                   2586123.0    1768302.0    1997371.0    2165836.0
#
#                            year_2014    year_2015    year_2016  cluster
# Antigua and Barbuda          22076.0      12302.0      11684.0      0.0
# Argentina                 23192978.0   19474206.0   33726527.0      0.0
# Aruba                       115701.0     159036.0      39318.0      0.0
# Bahrain                    4802690.0    1223609.0    3327892.0      0.0
# Barbados                    873313.0     705391.0     853629.0      0.0
# Belarus                    2260800.0    4411300.0    7070500.0      0.0
# Belgium                  583404583.0  482555430.0  526986497.0      0.0
# Bosnia Herzegovina         3557227.0    2103285.0    2765483.0      0.0
# Botswana                   2986366.0     864686.0     123773.0      0.0
# Brazil                   742199317.0  278156148.0  283752834.0      0.0
# Bulgaria                  18918602.0   26165941.0   43991133.0      0.0
# Cambodia                     64045.0     443375.0    3140451.0      0.0
# Chile                     10047606.0   46704766.0   26927709.0      0.0
# China                    585572411.0  597730692.0  646738226.0      0.0
# China, Hong Kong SAR       1750207.0    2379521.0    1373442.0      0.0
# Colombia                  58325573.0   50363951.0   55295058.0      0.0
# Costa Rica                 2994328.0    6989947.0    7304393.0      0.0
# Croatia                   68332362.0   45924835.0   68118211.0      0.0
# Cyprus                     6415321.0    3528689.0    4446976.0      0.0
# Czech Rep.               388362489.0  364759413.0  377920753.0      0.0
# Dominican Rep.            15883443.0    7654625.0    4010716.0      0.0
# Ecuador                     924908.0    2330268.0    1173496.0      0.0
# Egypt                     22212341.0   17374035.0   17699236.0      0.0
# El Salvador               12486373.0   13126436.0   10045941.0      0.0
# Estonia                   36529556.0   38795723.0   34736179.0      0.0
# Ethiopia                 332248542.0  332180377.0    2812952.0      0.0
# Finland                    4224564.0    7319329.0   10141592.0      0.0
# Georgia                   51390268.0   40217082.0   47336718.0      0.0
# Greece                    18208167.0   17101512.0   15292201.0      0.0
# Guyana                     1347486.0    1430053.0    1480306.0      0.0
# ...                              ...          ...          ...      ...
# Oman                      70939502.0  108872538.0  143321409.0      0.0
# Other Asia, nes            6574499.0    6113475.0    5622986.0      0.0
# Pakistan                   3532029.0    3042768.0    6326904.0      0.0
# Paraguay                     28000.0    3782600.0    2225350.0      0.0
# Peru                       7460848.0    9119965.0    8890143.0      0.0
# Philippines               14865003.0    2299545.0    1881722.0      0.0
# Poland                   204241351.0  161374487.0  151285712.0      0.0
# Portugal                 123530500.0  132138490.0  172485247.0      0.0
# Rep. of Korea              1819926.0    1129604.0    1666545.0      0.0
# Rep. of Moldova            6416177.0   10130939.0   10080029.0      0.0
# Romania                  407288753.0  344588129.0  393121289.0      0.0
# Russian Federation        28924797.0   21513407.0   22644710.0      0.0
# Rwanda                     7525578.0    6698441.0    6512695.0      0.0
# Senegal                     219013.0     251527.0     344804.0      0.0
# Serbia                    39198505.0   58622525.0   38429761.0      0.0
# Seychelles                  241882.0     181984.0     292121.0      0.0
# Singapore                  5264460.0    6266662.0    5781515.0      0.0
# Slovakia                 270077406.0  206883978.0  215151441.0      0.0
# South Africa              57996510.0   62012441.0   62085259.0      0.0
# Spain                    643230013.0  649300011.0  693375825.0      0.0
# Sri Lanka                  1022059.0     994973.0     726637.0      0.0
# Sweden                    34312560.0   18504772.0   20856893.0      0.0
# Switzerland               24307215.0   25783994.0   26352722.0      0.0
# TFYR of Macedonia          2550301.0    2397210.0     866484.0      0.0
# Tunisia                    1360303.0     931756.0    1038792.0      0.0
# Turkey                    26720290.0   34472551.0   27913652.0      0.0
# United Kingdom           669021853.0  674894717.0  680027773.0      0.0
# United Rep. of Tanzania    1604889.0    8420082.0     999289.0      0.0
# Uruguay                  145227211.0  150229339.0  200487044.0      0.0
# Zimbabwe                   2970036.0    3892232.0    3069522.0      0.0
#
# [86 rows x 8 columns]
